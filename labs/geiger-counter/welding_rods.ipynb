# %%
# welding_rods.ipynb

# Cell 01 - Prepare datafile to store counts of decay events

from lab_utils import DataFile, GeigerCounter

datafile = DataFile("counts_per_rod.csv")
datafile.create_slots(6)
print(f'Datafile "{datafile.file_name}" initialized.')

# %%
# Cell 02 - Insert rods 1 & 2 into BOTTOM row
count = GeigerCounter.get_count()
datafile.update_slot(1, count)

# %%
# Cell 03 - Insert rods 3 & 4 into BOTTOM row
count = GeigerCounter.get_count()
datafile.update_slot(2, count)

# %%
# Cell 04 - Insert rods 5 & 6 into BOTTOM row
count = GeigerCounter.get_count()
datafile.update_slot(3, count)

# %%
# Cell 05 - Insert rods 7 & 8 into TOP row
count = GeigerCounter.get_count()
datafile.update_slot(4, count)

# %%
# Cell 06 - Insert rods 9 & 10 into TOP row
count = GeigerCounter.get_count()
datafile.update_slot(5, count)

# %%
# Cell 07 - Insert rods 11 & 12 into TOP row
count = GeigerCounter.get_count()
datafile.update_slot(6, count)

# %%
# Cell 08 - Determine the relationship bewteen radiation absorption vs. number of rods
# %run ./plot_counts_per_rod.ipynb
