# %%
# thorium_mantle.ipynb

# Cell 01 - Prepare datafile to store counts of decay events

from lab_utils import DataFile, GeigerCounter

datafile = DataFile("counts_per_distance.csv")
datafile.create_slots(7)
print(f'Datafile "{datafile.file_name}" initialized.')

# %%
# Cell 02 - Move stopper brick to 1st row
count = GeigerCounter.get_count()
datafile.update_slot(1, count)

# %%
# Cell 03 - Move stopper brick to 2nd row
count = GeigerCounter.get_count()
datafile.update_slot(2, count)

# %%
# Cell 04 - Move stopper brick to 3rd row
count = GeigerCounter.get_count()
datafile.update_slot(3, count)

# %%
# Cell 05 - Move stopper brick to 4th row
count = GeigerCounter.get_count()
datafile.update_slot(4, count)

# %%
# Cell 06 - Move stopper brick to 5th row
count = GeigerCounter.get_count()
datafile.update_slot(5, count)

# %%
# Cell 07 - Move stopper brick to 6th row
count = GeigerCounter.get_count()
datafile.update_slot(6, count)

# %%
# Cell 08 - Completely remove stopper brick
count = GeigerCounter.get_count()
datafile.update_slot(7, count)

# %%
# Cell 09 - Determine the relationship bewteen radiation absorption vs. distance
# %run ./plot_counts_per_distance.ipynb
